# %%
# Silver Orchestration Notebook
# Sequentially triggers all Silver notebooks

silver_notebooks = [
    
    '/Users/dannywong1089@gmail.com/Databricks-Building-a-Data-Lakehouse/silver tables/silver_crm_prd_info',
    '/Users/dannywong1089@gmail.com/Databricks-Building-a-Data-Lakehouse/silver tables/silver_crm_cust_info','/Users/dannywong1089@gmail.com/Databricks-Building-a-Data-Lakehouse/silver tables/silver_crm_sales_details',
    '/Users/dannywong1089@gmail.com/Databricks-Building-a-Data-Lakehouse/silver tables/silver_erp_px_cat_g1v2',
    '/Users/dannywong1089@gmail.com/Databricks-Building-a-Data-Lakehouse/silver tables/silver_erp_loc_a101',
    '/Users/dannywong1089@gmail.com/Databricks-Building-a-Data-Lakehouse/silver tables/silver_erp_cust_az12'
]

results = {}
for notebook_path in silver_notebooks:
    try:
        result = dbutils.notebook.run(notebook_path, 60)
        results[notebook_path] = result
    except Exception as e:
        results[notebook_path] = f'Error: {str(e)}'

print('Silver orchestration results:')
for nb, res in results.items():
    print(f'{nb}: {res}')
